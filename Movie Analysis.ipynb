# %%
# Exploratory Data Analysis -

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
movie_list_1 = pd.read_csv(r"S:\Datasets\EDA Project datasets\Movie dataset\IMDb_Dataset_2.csv")
movie_list_2 = pd.read_csv(r"S:\Datasets\EDA Project datasets\Movie dataset\IMDb_Dataset_3.csv")
movie_list_3 = pd.read_csv(r"S:\Datasets\EDA Project datasets\Movie dataset\IMDb_Dataset.csv")

# %%
movie_list_1.head()
# Out:
#                           Title  IMDb Rating  Year Certificates        Genre  \
# 0              End of the Spear          6.8  2005        PG-13    Adventure
# 1                Elvira Madigan          7.0  1967           PG    Biography
# 2  The Kid Stays in the Picture          7.3  2002            R  Documentary
# 3                 It Ain't Over          8.2  2022           PG  Documentary
# 4                        Mahler          7.0  1974           PG    Biography
#
#            Director                                   Star Cast  MetaScore  \
# 0         Jim Hanon         Louie LeonardoChad AllenJack Guzman       45.0
# 1      Bo Widerberg  Pia DegermarkThommy BerggrenLennart Malmer       66.0
# 2  Nanette Burstein          Robert EvansEddie AlbertPeter Bart       75.0
# 3       Sean Mullin          Andy AndresRoger AngellMarty Appel       79.0
# 4       Ken Russell      Robert PowellGeorgina HaleLee Montague       66.0
#
# ...

# %%
movie_list_2.head()
# Out:
#                            Title         Director         Star Cast  Year  \
# 0        The Biggest Little Farm     John Chester      John Chester  2018
# 1         Pokémon the Movie 2000  Kunihiko Yuyama   Veronica Taylor  1999
# 2  When Hitler Stole Pink Rabbit    Caroline Link  Riva Krymalowski  2019
# 3     Return from Witch Mountain       John Hough       Bette Davis  1978
# 4                   Summer Magic    James Neilson      Hayley Mills  1963
#
#    IMDb Rating  MetaScore Certificates        Genre Second_Genre Third_Genre  \
# 0          8.0       73.0           PG  Documentary       Family      Family
# 1          6.1       28.0            G    Animation       Action   Adventure
# 2          7.0       54.0           PG    Biography        Drama      Family
# 3          5.7       51.0            G    Adventure       Family     Fantasy
# 4          6.9       57.1            G       Comedy       Family     Musical
#
# ...

# %%
movie_list_3.head()
# Out:
#                                            Title  IMDb Rating  Year  \
# 0                                      Gladiator          8.5  2000
# 1  Mission: Impossible - Dead Reckoning Part One          7.7  2023
# 2           Rebel Moon - Part Two: The Scargiver          5.2  2024
# 3                           Inglourious Basterds          8.4  2009
# 4                                    Borderlands          7.1  2024
#
#   Certificates      Genre               Director  \
# 0            R     Action           Ridley Scott
# 1        PG-13     Action  Christopher McQuarrie
# 2        PG-13     Action            Zack Snyder
# 3            R  Adventure      Quentin Tarantino
# 4            R     Action               Eli Roth
#
#                                    Star Cast  MetaScore  Duration (minutes)
# 0  David FranzoniJohn LoganWilliam Nicholson       67.0               155.0
# 1         Tom CruiseHayley AtwellVing Rhames       81.0               163.0
# ...

# %%
movie_list_1.shape
# Out:
# (3173, 10)

# %%
print(movie_list_1.info())
print(movie_list_2.info())
print(movie_list_3.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3173 entries, 0 to 3172
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Title               3173 non-null   object
#  1   IMDb Rating         3173 non-null   float64
#  2   Year                3173 non-null   int64
#  3   Certificates        3173 non-null   object
#  4   Genre               3173 non-null   object
#  5   Director            3173 non-null   object
#  6   Star Cast           3173 non-null   object
#  7   MetaScore           3173 non-null   float64
#  8   Poster-src          3173 non-null   object
#  9   Duration (minutes)  3173 non-null   float64
# dtypes: float64(3), int64(1), object(6)
# memory usage: 248.0+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
# ...

# %%
print(movie_list_1.nunique())
print(movie_list_2.nunique())
print(movie_list_3.nunique())
# Out:
# Title                 2739
# IMDb Rating             48
# Year                    93
# Certificates            16
# Genre                   17
# Director              2089
# Star Cast             2592
# MetaScore               78
# Poster-src            2623
# Duration (minutes)     156
# dtype: int64
# Title                  966
# Director               659
# Star Cast              720
# Year                    88
# IMDb Rating             47
# MetaScore               82
# Certificates            12
# Genre                    9
# Second_Genre            14
# Third_Genre             16
# Poster-src            1000
# Duration (minutes)      96
# dtype: int64
# Title                 251
# IMDb Rating            45
# Year                   47
# Certificates           11
# Genre                  10
# Director              199
# Star Cast             247
# MetaScore              66
# Duration (minutes)     79
# dtype: int64

# %%
dup=list(movie_list_1.duplicated())
count = 0
for i in dup:
    if i==True:
        count+=1
print(count)

# movie_list_1.duplicated().sum() - we can use this method also
# Out:
# 411

# %%
movie_list_1.drop_duplicates(inplace=True)
print(movie_list_1.duplicated().sum())
# Out:
# 0

# %%
movie_list_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2762 entries, 0 to 3172
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Title               2762 non-null   object
#  1   IMDb Rating         2762 non-null   float64
#  2   Year                2762 non-null   int64
#  3   Certificates        2762 non-null   object
#  4   Genre               2762 non-null   object
#  5   Director            2762 non-null   object
#  6   Star Cast           2762 non-null   object
#  7   MetaScore           2762 non-null   float64
#  8   Poster-src          2762 non-null   object
#  9   Duration (minutes)  2762 non-null   float64
# dtypes: float64(3), int64(1), object(6)
# memory usage: 237.4+ KB

# %%
movie_list_1.shape
# Out:
# (2762, 10)

# %%
# Visualization -

# %%
columns = ['IMDb Rating','Year','Certificates','Genre','MetaScore']

for col in columns:
    plt.figure(figsize=(14,6))
    sns.countplot(movie_list_1,x=col)
    plt.xticks(rotation=90)
    plt.show()

# %%
sns.lineplot(movie_list_1,x='Genre',y='IMDb Rating')
sns.set_style('darkgrid')
plt.xticks(rotation=90)
plt.show()

# %%
sns.scatterplot(movie_list_1,x='Genre',y='IMDb Rating')
sns.set_style('darkgrid')
plt.xticks(rotation=90)
plt.show()

# %%
cols = ['IMDb Rating','Year','MetaScore','Duration (minutes)']

sns.heatmap(movie_list_1[cols].corr(),annot=True,fmt='.2g')
plt.show()

# %%
sns.pairplot(movie_list_1)
sns.set_style('darkgrid')
plt.show()
